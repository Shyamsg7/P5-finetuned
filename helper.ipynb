# %%
# # write a code which takes input like this and produce output like this
 
 
# # <!DOCTYPE html><html><head><title>Google Drive - Virus scan warning</title><meta http-equiv="content-type" content="text/html; charset=utf-8"/><style nonce="C1Hm-1pmctYMBfzmiDhvJw">.goog-link-button{position:relative;color:#15c;text-decoration:underline;cursor:pointer}.goog-link-button-disabled{color:#ccc;text-decoration:none;cursor:default}body{color:#222;font:normal 13px/1.4 arial,sans-serif;margin:0}.grecaptcha-badge{visibility:hidden}.uc-main{padding-top:50px;text-align:center}#uc-dl-icon{display:inline-block;margin-top:16px;padding-right:1em;vertical-align:top}#uc-text{display:inline-block;max-width:68ex;text-align:left}.uc-error-caption,.uc-warning-caption{color:#222;font-size:16px}#uc-download-link{text-decoration:none}.uc-name-size a{color:#15c;text-decoration:none}.uc-name-size a:visited{color:#61c;text-decoration:none}.uc-name-size a:active{color:#d14836;text-decoration:none}.uc-footer{color:#777;font-size:11px;padding-bottom:5ex;padding-top:5ex;text-align:center}.uc-footer a{color:#15c}.uc-footer a:visited{color:#61c}.uc-footer a:active{color:#d14836}.uc-footer-divider{color:#ccc;width:100%}.goog-inline-block{position:relative;display:-moz-inline-box;display:inline-block}* html .goog-inline-block{display:inline}*:first-child+html .goog-inline-block{display:inline}sentinel{}</style><link rel="icon" href="//ssl.gstatic.com/docs/doclist/images/drive_2022q3_32dp.png"/></head><body><div class="uc-main"><div id="uc-dl-icon" class="image-container"><div class="drive-sprite-aux-download-file"></div></div><div id="uc-text"><p class="uc-warning-caption">Google Drive can't scan this file for viruses.</p><p class="uc-warning-subcaption"><span class="uc-name-size"><a href="/open?id=1uesez6E-q9WtS5VO07cXDoJDQz37oq0M&amp;authuser=0">beauty-small.pth</a> (232M)</span> is too large for Google to scan for viruses. Would you still like to download this file?</p><form id="download-form" action="https://drive.usercontent.google.com/download" method="get"><input type="submit" id="uc-download-link" class="goog-inline-block jfk-button jfk-button-action" value="Download anyway"/><input type="hidden" name="id" value="1uesez6E-q9WtS5VO07cXDoJDQz37oq0M"><input type="hidden" name="export" value="download"><input type="hidden" name="authuser" value="0"><input type="hidden" name="confirm" value="t"><input type="hidden" name="uuid" value="68b0c41d-264c-40fa-aff6-800dd6f073d5"><input type="hidden" name="at" value="APZUnTXeSUtu1FDhihqj1Rbc-QpW:1715861553470"></form></div></div><div class="uc-footer"><hr class="uc-footer-divider"></div></body></html>
 
# # and output is like this
 
 
# #  wget --no-check-certificate 'https://drive.usercontent.google.com/download?id=1uesez6E-q9WtS5VO07cXDoJDQz37oq0M&export=download&authuser=0&confirm=t&uuid=b1720b22-e42d-4f
# # 72-99ee-4332d61bb515&at=APZUnTX-YfazUggnkYQwCXhEu0PP:1715861362398'
# # -O P5/snap/beauty-small.pth  

# from bs4 import BeautifulSoup
 
# def parse_html_to_wget_command(html_content, output_filename):
#     # Parse HTML content
#     soup = BeautifulSoup(html_content, 'html.parser')
   
#     # Find download link
#     download_link = soup.find('a', href=True)
#     download_href = download_link['href']
   
#     # Find UUID
#     uuid_input = soup.find('input', {'name': 'uuid'})
#     uuid_value = uuid_input['value']
   
#     # Find at value
#     at_input = soup.find('input', {'name': 'at'})
#     at_value = at_input['value']
   
   
#     # Construct wget command have to add uuid_value and at value also
#     # output should be like this wget --no-check-certificate 'https://drive.usercontent.google.com/download?id=1uesez6E-q9WtS5VO07cXDoJDQz37oq0M&export=download&authuser=0&confirm=t&uuid=b1720b22-e42d-4f72-99ee-4332d61bb515&at=APZUnTX-YfazUggnkYQwCXhEu0PP:1715861362398' -O P5/snap/beauty-small.pth  
   
#     wget_command = f"wget --no-check-certificate 'https://drive.usercontent.google.com/download?id=1qGxgmx7G_WB7JE4Cn_bEcZ_o_NAJLE3G&export=download&authuser=0&confirm=t&uuid={uuid_value}&at={at_value}' -O {output_filename}"
   
   
#     return wget_command
 
 
# html_input = """
# <!DOCTYPE html><html><head><title>Google Drive - Virus scan warning</title><meta http-equiv="content-type" content="text/html; charset=utf-8"/><style nonce="tDlrLJfD2BVKxuBry1XTYg">.goog-link-button{position:relative;color:#15c;text-decoration:underline;cursor:pointer}.goog-link-button-disabled{color:#ccc;text-decoration:none;cursor:default}body{color:#222;font:normal 13px/1.4 arial,sans-serif;margin:0}.grecaptcha-badge{visibility:hidden}.uc-main{padding-top:50px;text-align:center}#uc-dl-icon{display:inline-block;margin-top:16px;padding-right:1em;vertical-align:top}#uc-text{display:inline-block;max-width:68ex;text-align:left}.uc-error-caption,.uc-warning-caption{color:#222;font-size:16px}#uc-download-link{text-decoration:none}.uc-name-size a{color:#15c;text-decoration:none}.uc-name-size a:visited{color:#61c;text-decoration:none}.uc-name-size a:active{color:#d14836;text-decoration:none}.uc-footer{color:#777;font-size:11px;padding-bottom:5ex;padding-top:5ex;text-align:center}.uc-footer a{color:#15c}.uc-footer a:visited{color:#61c}.uc-footer a:active{color:#d14836}.uc-footer-divider{color:#ccc;width:100%}.goog-inline-block{position:relative;display:-moz-inline-box;display:inline-block}* html .goog-inline-block{display:inline}*:first-child+html .goog-inline-block{display:inline}sentinel{}</style><link rel="icon" href="//ssl.gstatic.com/docs/doclist/images/drive_2022q3_32dp.png"/></head><body><div class="uc-main"><div id="uc-dl-icon" class="image-container"><div class="drive-sprite-aux-download-file"></div></div><div id="uc-text"><p class="uc-warning-caption">Google Drive can't scan this file for viruses.</p><p class="uc-warning-subcaption"><span class="uc-name-size"><a href="/open?id=1qGxgmx7G_WB7JE4Cn_bEcZ_o_NAJLE3G&amp;authuser=0">P5_data.zip</a> (1.2G)</span> is too large for Google to scan for viruses. Would you still like to download this file?</p><form id="download-form" action="https://drive.usercontent.google.com/download" method="get"><input type="submit" id="uc-download-link" class="goog-inline-block jfk-button jfk-button-action" value="Download anyway"/><input type="hidden" name="id" value="1qGxgmx7G_WB7JE4Cn_bEcZ_o_NAJLE3G"><input type="hidden" name="export" value="download"><input type="hidden" name="authuser" value="0"><input type="hidden" name="confirm" value="t"><input type="hidden" name="uuid" value="e3df59f4-febb-4bf9-808a-be8882f0c12b"><input type="hidden" name="at" value="APZUnTXRxMQF7Nv5ApSGjSRoFArC:1716441832190"></form></div></div><div class="uc-footer"><hr class="uc-footer-divider"></div></body></html>"""
# output_filename = "beauty-small.pth"
# print(parse_html_to_wget_command(html_input, output_filename))

# wget_command = f"wget --no-check-certificate 'https://drive.usercontent.google.com/download?id={id_value}&export=download&authuser=0&confirm=t&uuid={uuid_value}&at={at_value}' -O {output_filename}"

from bs4 import BeautifulSoup
 
def parse_html_to_wget_command(html_content, output_filename):
    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
   
   
    # Find download link
    download_link = soup.find('a', href=True)
    download_href = download_link['href']
   
    # Find ID
    id_input = soup.find('input', {'name': 'id'})
    id_value = id_input['value']
   
    # Find UUID
    uuid_input = soup.find('input', {'name': 'uuid'})
    uuid_value = uuid_input['value']
   
    # Find at value
    at_input = soup.find('input', {'name': 'at'})
    at_value = at_input['value']
   
   
    # Construct wget command have to add uuid_value and at value also
    # output should be like this wget --no-check-certificate 'https://drive.usercontent.google.com/download?id=1uesez6E-q9WtS5VO07cXDoJDQz37oq0M&export=download&authuser=0&confirm=t&uuid=b1720b22-e42d-4f72-99ee-4332d61bb515&at=APZUnTX-YfazUggnkYQwCXhEu0PP:1715861362398' -O P5/snap/beauty-small.pth  
   
    wget_command = f"wget --no-check-certificate 'https://drive.usercontent.google.com/download?id={id_value}&export=download&authuser=0&confirm=t&uuid={uuid_value}&at={at_value}' -O {output_filename}"
   
   
    return wget_command

html_input ="""
<!DOCTYPE html><html><head><title>Google Drive - Virus scan warning</title><meta http-equiv="content-type" content="text/html; charset=utf-8"/><style nonce="g697jBfDiWtjiMsGss2S5g">.goog-link-button{position:relative;color:#15c;text-decoration:underline;cursor:pointer}.goog-link-button-disabled{color:#ccc;text-decoration:none;cursor:default}body{color:#222;font:normal 13px/1.4 arial,sans-serif;margin:0}.grecaptcha-badge{visibility:hidden}.uc-main{padding-top:50px;text-align:center}#uc-dl-icon{display:inline-block;margin-top:16px;padding-right:1em;vertical-align:top}#uc-text{display:inline-block;max-width:68ex;text-align:left}.uc-error-caption,.uc-warning-caption{color:#222;font-size:16px}#uc-download-link{text-decoration:none}.uc-name-size a{color:#15c;text-decoration:none}.uc-name-size a:visited{color:#61c;text-decoration:none}.uc-name-size a:active{color:#d14836;text-decoration:none}.uc-footer{color:#777;font-size:11px;padding-bottom:5ex;padding-top:5ex;text-align:center}.uc-footer a{color:#15c}.uc-footer a:visited{color:#61c}.uc-footer a:active{color:#d14836}.uc-footer-divider{color:#ccc;width:100%}.goog-inline-block{position:relative;display:-moz-inline-box;display:inline-block}* html .goog-inline-block{display:inline}*:first-child+html .goog-inline-block{display:inline}sentinel{}</style><link rel="icon" href="//ssl.gstatic.com/docs/doclist/images/drive_2022q3_32dp.png"/></head><body><div class="uc-main"><div id="uc-dl-icon" class="image-container"><div class="drive-sprite-aux-download-file"></div></div><div id="uc-text"><p class="uc-warning-caption">Google Drive can't scan this file for viruses.</p><p class="uc-warning-subcaption"><span class="uc-name-size"><a href="/open?id=1uesez6E-q9WtS5VO07cXDoJDQz37oq0M&amp;authuser=0">beauty-small.pth</a> (232M)</span> is too large for Google to scan for viruses. Would you still like to download this file?</p><form id="download-form" action="https://drive.usercontent.google.com/download" method="get"><input type="submit" id="uc-download-link" class="goog-inline-block jfk-button jfk-button-action" value="Download anyway"/><input type="hidden" name="id" value="1uesez6E-q9WtS5VO07cXDoJDQz37oq0M"><input type="hidden" name="export" value="download"><input type="hidden" name="authuser" value="0"><input type="hidden" name="confirm" value="t"><input type="hidden" name="uuid" value="48fe65d9-badb-4d99-bf03-5cea1c5e3373"><input type="hidden" name="at" value="APZUnTXavMgkaP1NpV8VsoHhT4yW:1716453181668"></form></div></div><div class="uc-footer"><hr class="uc-footer-divider"></div></body></html>""" 
output_filename = "./snap/beauty_small.pth"
print(parse_html_to_wget_command(html_input, output_filename))
# Out:
# wget --no-check-certificate 'https://drive.usercontent.google.com/download?id=1uesez6E-q9WtS5VO07cXDoJDQz37oq0M&export=download&authuser=0&confirm=t&uuid=48fe65d9-badb-4d99-bf03-5cea1c5e3373&at=APZUnTXavMgkaP1NpV8VsoHhT4yW:1716453181668' -O ./snap/beauty_small.pth
